# %% [markdown]
# <a href="https://colab.research.google.com/github/arefosco/panorama-covid-19-brasil/blob/main/Projeto_Panorama_do_COVID_19_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Data Science and Data Analysis**
# *by [Andre Refosco](https://github.com/arefosco)*
#
#
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-andrerefosco-blue.svg)](https://www.linkedin.com/in/andrerefosco/)  [![GitHub](https://img.shields.io/badge/GitHub-arefosco-brightgreen.svg)](https://github.com/arefosco)
# ---

# %% [markdown]
# # Panorama do COVID-19 no Mundo e no Brasil
#
# <center><img alt="Colaboratory logo" width="50%" src="https://cdn-images-1.medium.com/max/1200/0*LiDfRp1he88e2L3a"></center>
#
# Em 31 de dezembro de 2019, a Organização Mundial da Saúde (OMS) foi alertada sobre vários casos de pneumonia na cidade de Wuhan, província de Hubei, na República Popular da China. Tratava-se de uma nova cepa (tipo) de coronavírus que não havia sido identificada antes em seres humanos.
#
# Uma semana depois, em 7 de janeiro de 2020, as autoridades chinesas confirmaram que haviam identificado um novo tipo de coronavírus. Os coronavírus estão por toda parte. Eles são a segunda principal causa de resfriado comum (após rinovírus) e, até as últimas décadas, raramente causavam doenças mais graves em humanos do que o resfriado comum.
#
# Ao todo, sete coronavírus humanos (HCoVs) já foram identificados: HCoV-229E, HCoV-OC43, HCoV-NL63, HCoV-HKU1, SARS-COV (que causa síndrome respiratória aguda grave), MERS-COV (que causa síndrome respiratória do Oriente Médio) e o, mais recente, novo coronavírus (que no início foi temporariamente nomeado 2019-nCoV e, em 11 de fevereiro de 2020, recebeu o nome de SARS-CoV-2). Esse novo coronavírus é responsável por causar a doença COVID-19.
#
# A OMS tem trabalhado com autoridades chinesas e especialistas globais desde o dia em que foi informada, para aprender mais sobre o vírus, como ele afeta as pessoas que estão doentes, como podem ser tratadas e o que os países podem fazer para responder.
#
# A Organização Pan-Americana da Saúde (OPAS) tem prestado apoio técnico aos países das Américas e recomendado manter o sistema de vigilância alerta, preparado para detectar, isolar e cuidar precocemente de pacientes infectados com o novo coronavírus.
#
#
# *fonte: https://www.paho.org/pt/covid19/historico-da-pandemia-covid-19*

# %% [markdown]
# ## Obtenção dos Dados
#
# A fonte de dados utilizada neste projeto foi obtida junto ao repositório do github da [**Our World in Data**](https://github.com/owid/covid-19-data/tree/master/public/data). Esta iniciativa vem compilando e monitorando os dados relativos a pandemia global do COVID-19.
#
#
# Dentro desta compilação de dados estão contidas diversas informações coletadas, dentre elas casos e mortes confirmadas que foram obtidas através do [**COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University**](https://github.com/CSSEGISandData/COVID-19). Além disso, dentro do rol de dados estão contidos dados relativos a casos hospitalizados e de tratamento intensivo, testes de COVID-19, vacinação, entre outros. Todos estes dados são obtidos e adicionados a partir de varias fontes e diferentes datas de alimentação.
#
#
# Entretanto, neste projeto iremos fazer duas análises exploratórias. A primeira fazendo uma avaliação dos casos e mortes confirmadas ao redor do mundo, obtendo os maiores índices para ambos. Já na segunda, faremos uma avaliação da situação do Brasil, bem como, a diferença entre a data do primeiro caso e da primeira morte.

# %% [markdown]
# ### Dicionário de Variáveis
#
# As variáveis constantes neste dataset e utilizadas para o projeto são as originais dos dados utilizados:
#
# * `iso_code`: ISO 3166-1 alpha-3 – Código de Países de três letras. Observe que as regiões definidas por OWID (por exemplo, continentes como 'Europa') contêm o prefixo 'OWID_'. *(three-letter country codes. Note that OWID-defined regions (e.g. continents like 'Europe') contain prefix 'OWID_'.)*
#
# * `continent`: Continente *(Continent of the geographical location)*.
#
# * `location`: Localização geográfica. A localização 'Internacional' considera regiões especiais (cruzeiros "Diamond Princess" e "MS Zaandam") *(Geographical location. Location 'International' considers special regions ("Diamond Princess" and "MS Zaandam" cruises))*
#
# * `date`: Data da Observação *(Date of observation)*.
#
# * `total_cases`: Total de casos confirmados de COVID-19. As contagens podem incluir casos prováveis, quando relatados. *(Total confirmed cases of COVID-19. Counts can include probable cases, where reported)*
#
# * `new_cases`: Novos casos confirmados de COVID-19. As contagens podem incluir casos prováveis, quando relatados. Em casos raros em que nossa fonte relata uma alteração diária negativa devido a uma correção de dados, definimos essa métrica como NA. *(New confirmed cases of COVID-19. Counts can include probable cases, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA)*
#
# * `new_cases_smoothed`: Novos casos confirmados de COVID-19 (suavização de 7 dias). As contagens podem incluir casos prováveis, quando relatados. *(New confirmed cases of COVID-19 (7-day smoothed). Counts can include probable cases, where reported)*
#
# * `total_deaths`: Total de mortes atribuídas à COVID-19. As contagens podem incluir mortes prováveis, quando relatadas. *(Total deaths attributed to COVID-19. Counts can include probable deaths, where reported)*
#
# * `new_deaths`: Novas mortes atribuídas à COVID-19. As contagens podem incluir mortes prováveis, quando relatadas. Em casos raros em que nossa fonte relata uma alteração diária negativa devido a uma correção de dados, definimos essa métrica como NA. *(New deaths attributed to COVID-19. Counts can include probable deaths, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA)*
#
# * `new_deaths_smoothed`: Novas mortes atribuídas ao COVID-19 (suavização de 7 dias). As contagens podem incluir mortes prováveis, quando relatadas. *(New deaths attributed to COVID-19 (7-day smoothed). Counts can include probable deaths, where reported)*
#
# * `total_cases_per_million`: Total de casos confirmados de COVID-19 por 1.000.000 de pessoas. As contagens podem incluir casos prováveis, quando relatados. *(Total confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported)*
#
# * `new_cases_per_million`: Novos casos confirmados de COVID-19 por 1.000.000 de pessoas. As contagens podem incluir casos prováveis, quando relatados. *(New confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported)*
#
# * `new_cases_smoothed_per_million`: Novos casos confirmados de COVID-19 (suavização de 7 dias) por 1.000.000 de pessoas. As contagens podem incluir casos prováveis, quando relatados. *(New confirmed cases of COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable cases, where reported)*
#
# * `total_deaths_per_million`: Total de mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. As contagens podem incluir mortes prováveis, quando relatadas. *(Total deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported)*
#
# * `new_deaths_per_million`: Novas mortes atribuídas ao COVID-19 por 1.000.000 de pessoas. As contagens podem incluir mortes prováveis, quando relatadas. *(New deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported)*
#
# * `new_deaths_smoothed_per_million`: Novas mortes atribuídas ao COVID-19 (suavização de 7 dias) por 1.000.000 de pessoas. As contagens podem incluir mortes prováveis, quando relatadas. *(New deaths attributed to COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable deaths, where reported)*
#
# * `reproduction_rate`: Estimativa em tempo real da taxa efetiva de reprodução (R) do COVID-19. Consulte https://github.com/crondonm/TrackingR/tree/main/Estimates-Database *(Real-time estimate of the effective reproduction rate (R) of COVID-19. See https://github.com/crondonm/TrackingR/tree/main/Estimates-Database)*
#
# * `icu_patients`: Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia. *(Number of COVID-19 patients in intensive care units (ICUs) on a given day)*
#
# * `icu_patients_per_million`: Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas. *(Number of COVID-19 patients in intensive care units (ICUs) on a given day per 1,000,000 people)*
#
# * `hosp_patients`: Número de pacientes com COVID-19 internados em um determinado dia. *(Number of COVID-19 patients in hospital on a given day)*
#
# * `hosp_patients_per_million`: Número de pacientes com COVID-19 hospitalizados em um determinado dia por 1.000.000 de pessoas. *(Number of COVID-19 patients in hospital on a given day per 1,000,000 people)*
#
# * `weekly_icu_admissions`: Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana (data do relatório e os 6 dias anteriores). *(Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week (reporting date and the preceeding 6 days))*
#
# * `weekly_icu_admissions_per_million`: Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana por 1.000.000 de pessoas (data do relatório e os 6 dias anteriores). *(Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week per 1,000,000 people (reporting date and the preceeding 6 days))*
#
# * `weekly_hosp_admissions`: Número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana (data do relatório e os 6 dias anteriores). *(Number of COVID-19 patients newly admitted to hospitals in a given week (reporting date and the preceeding 6 days))*
#
# * `weekly_hosp_admissions_per_million`: Número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana por 1.000.000 de pessoas (data do relatório e os 6 dias anteriores). *(Number of COVID-19 patients newly admitted to hospitals in a given week per 1,000,000 people (reporting date and the preceeding 6 days))*
#
# * `total_tests`: Total de testes de COVID-19 realizados. *(Total tests for COVID-19)*
#
# * `new_tests`: Novos testes para COVID-19 (calculados apenas para dias consecutivos). *(New tests for COVID-19 (only calculated for consecutive days))*
#
# * `total_tests_per_thousand`: Total de testes para COVID-19 por 1.000 pessoas. *(Total tests for COVID-19 per 1,000 people)*
#
# * `new_tests_per_thousand`: Novos testes para COVID-19 por 1.000 pessoas. *(New tests for COVID-19 per 1,000 people)*
#
# * `new_tests_smoothed`: Novos testes para COVID-19 (7 dias suavizados). Para os países que não relatam dados de testes diariamente, assumimos que os testes mudaram igualmente diariamente em todos os períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, cuja média é calculada em uma janela contínua de 7 dias. *(New tests for COVID-19 (7-day smoothed). For countries that don't report testing data on a daily basis, we assume that testing changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window)*
#
# * `new_tests_smoothed_per_thousand`: Novos testes para COVID-19 (7 dias suavizados) por 1.000 pessoas. *(New tests for COVID-19 (7-day smoothed) per 1,000 people)*
#
# * `positive_rate`: A parcela de testes positivos para COVID-19, dada como uma média contínua de 7 dias (este é o inverso de tests_per_case). *(The share of COVID-19 tests that are positive, given as a rolling 7-day average (this is the inverse of tests_per_case))*
#
# * `tests_per_case`: Testes realizados por novo caso confirmado de COVID-19, dados como uma média contínua de 7 dias (este é o inverso de Positive_rate). *(Tests conducted per new confirmed case of COVID-19, given as a rolling 7-day average (this is the inverse of positive_rate))*
#
# * `tests_units`: Unidades usadas pelo local para relatar seus dados de teste. Um arquivo de país não pode conter unidades mistas. Todas as métricas relativas aos dados de teste usam a unidade de teste especificada. As unidades válidas são 'pessoas testadas' (número de pessoas testadas), 'testes realizados' (número de testes realizados. uma única pessoa pode ser testada mais de uma vez em um determinado dia) e 'amostras testadas' (número de amostras testadas. Em alguns casos, mais de uma amostra pode ser necessária para realizar um determinado teste.). *(Units used by the location to report its testing data. A country file can't contain mixed units. All metrics concerning testing data use the specified test unit. Valid units are 'people tested' (number of people tested), 'tests performed' (number of tests performed. a single person can be tested more than once in a given day) and 'samples tested' (number of samples tested. In some cases, more than one sample may be required to perform a given test.))*
#
# * `total_vaccinations`: Número total de doses de vacinação contra COVID-19 administradas. *(Total number of COVID-19 vaccination doses administered)*
#
# * `people_vaccinated`: Número total de pessoas que receberam pelo menos uma dose de vacina. *(Total number of people who received at least one vaccine dose)*
#
# * `people_fully_vaccinated`: Número total de pessoas que receberam todas as doses prescritas pelo protocolo inicial de vacinação. *(Total number of people who received all doses prescribed by the initial vaccination protocol)*
#
# * `total_boosters`: Número total de doses de reforço da vacinação contra COVID-19 administradas (doses administradas além do número prescrito pelo protocolo de vacinação). *(Total number of COVID-19 vaccination booster doses administered (doses administered beyond the number prescribed by the vaccination protocol))*
#
# * `new_vaccinations`: Novas doses de vacinação COVID-19 administradas (calculadas apenas para dias consecutivos). *(New COVID-19 vaccination doses administered (only calculated for consecutive days))*
#
# * `new_vaccinations_smoothed`: Novas doses de vacinação COVID-19 administradas (suavização de 7 dias). Para países que não relatam dados de vacinação diariamente, assumimos que a vacinação mudou igualmente diariamente em todos os períodos em que nenhum dado foi relatado. Isso produz uma série completa de números diários, cuja média é calculada em uma janela contínua de 7 dias. *(New COVID-19 vaccination doses administered (7-day smoothed). For countries that don't report vaccination data on a daily basis, we assume that vaccination changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window)*
#
# * `total_vaccinations_per_hundred`: Número total de doses de vacinação contra COVID-19 administradas por 100 pessoas na população total. *(Total number of COVID-19 vaccination doses administered per 100 people in the total population)*
#
# * `people_vaccinated_per_hundred`: Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas na população total. *(Total number of people who received at least one vaccine dose per 100 people in the total population)*
#
# * `people_fully_vaccinated_per_hundred`: Número total de pessoas que receberam todas as doses prescritas pelo protocolo inicial de vacinação por 100 pessoas na população total. *(Total number of people who received all doses prescribed by the initial vaccination protocol per 100 people in the total population)*
#
# * `total_boosters_per_hundred`: Número total de doses de reforço da vacinação contra COVID-19 administradas por 100 pessoas na população total. *(Total number of COVID-19 vaccination booster doses administered per 100 people in the total population)*
#
# * `new_vaccinations_smoothed_per_million`: Novas doses de vacinação contra COVID-19 administradas (suavizadas em 7 dias) por 1.000.000 de pessoas na população total. *(New COVID-19 vaccination doses administered (7-day smoothed) per 1,000,000 people in the total population)*
#
# * `new_people_vaccinated_smoothed`: Número diário de pessoas que receberam a primeira dose da vacina (7 dias suavizados). *(Daily number of people receiving their first vaccine dose (7-day smoothed))*
#
# * `new_people_vaccinated_smoothed_per_hundred`: Número diário de pessoas que receberam a primeira dose da vacina (suavização de 7 dias) por 100 pessoas na população total. *(Daily number of people receiving their first vaccine dose (7-day smoothed) per 100 people in the total population)*
#
# * `stringency_index`: Índice de Severidade de Resposta do Governo: medida composta com base em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibições de viagens, reescalonados para um valor de 0 a 100 (100 = resposta mais rigorosa). *(Government Response Stringency Index: composite measure based on 9 response indicators including school closures, workplace closures, and travel bans, rescaled to a value from 0 to 100 (100 = strictest response))*
#
# * `population`: População (últimos valores disponíveis). Consulte https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv para obter a lista completa de fontes. *(Population (latest available values). See https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv for full list of sources)*
#
# * `population_density`: Número de pessoas dividido por área de terra, medida em quilômetros quadrados, ano mais recente disponível. *(Number of people divided by land area, measured in square kilometers, most recent year available)*
#
# * `median_age`: Idade média da população, projeção da ONU para 2020. *(Median age of the population, UN projection for 2020)*
#
# * `aged_65_older`: Parcela da população com 65 anos ou mais, ano mais recente disponível. *(Share of the population that is 65 years and older, most recent year available)*
#
# * `aged_70_older`: Proporção da população com 70 anos ou mais em 2015. *(Share of the population that is 70 years and older in 2015)*
#
# * `gdp_per_capita`: Produto interno bruto em paridade de poder de compra (dólares internacionais constantes de 2011), ano mais recente disponível. *(Gross domestic product at purchasing power parity (constant 2011 international dollars), most recent year available)*
#
# * `extreme_poverty`: Parcela da população que vive em extrema pobreza, ano mais recente disponível desde 2010. *(Share of the population living in extreme poverty, most recent year available since 2010)*
#
# * `cardiovasc_death_rate`: Taxa de mortalidade por doenças cardiovasculares em 2017 (número anual de mortes por 100.000 pessoas). *(Death rate from cardiovascular disease in 2017 (annual number of deaths per 100,000 people))*
#
# * `diabetes_prevalence`: Prevalência de diabetes (% da população de 20 a 79 anos) em 2017. *(Diabetes prevalence (% of population aged 20 to 79) in 2017)*
#
# * `female_smokers`: Proporção de mulheres que fumam, ano mais recente disponível. *(Share of women who smoke, most recent year available)*
#
# * `male_smokers`: Parcela de homens que fumam, ano mais recente disponível. *(Share of men who smoke, most recent year available)*
#
# * `handwashing_facilities`: Parcela da população com instalações básicas de lavagem das mãos nas instalações, ano mais recente disponível. *(Share of the population with basic handwashing facilities on premises, most recent year available)*
#
# * `hospital_beds_per_thousand`: Camas hospitalares por 1.000 pessoas, ano mais recente disponível desde 2010. *(Hospital beds per 1,000 people, most recent year available since 2010)*
#
# * `life_expectancy`: Expectativa de vida ao nascer em 2019. *(Life expectancy at birth in 2019)*
#
# * `human_development_index`: Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano – uma vida longa e saudável, conhecimento e um padrão de vida decente. Valores para 2019, importados de http://hdr.undp.org/en/indicators/137506. *(A composite index measuring average achievement in three basic dimensions of human development—a long and healthy life, knowledge and a decent standard of living. Values for 2019, imported from http://hdr.undp.org/en/indicators/137506)*
#
# * `excess_mortality`: Diferença percentual entre o número relatado de mortes semanais ou mensais em 2020–2021 e o número projetado de mortes para o mesmo período com base nos anos anteriores. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality. *(Percentage difference between the reported number of weekly or monthly deaths in 2020–2021 and the projected number of deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality)*
#
# * `excess_mortality_cumulative`: Diferença percentual entre o número acumulado de mortes desde 1º de janeiro de 2020 e as mortes projetadas cumulativas para o mesmo período com base nos anos anteriores. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality. *(Percentage difference between the cumulative number of deaths since 1 January 2020 and the cumulative projected deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality)*
#
# * `excess_mortality_cumulative_absolute`: Diferença cumulativa entre o número relatado de mortes desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base nos anos anteriores. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality. (Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality)*
#
# * `excess_mortality_cumulative_per_million`: Diferença cumulativa entre o número relatado de mortes desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base nos anos anteriores, por milhão de pessoas. Para obter mais informações, consulte https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality. *(Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years, per million people. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality)*

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Vamos importar os pacotes necessários e iniciar nossa Análise Exploratória.

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


# %matplotlib inline

# importar o dataset COVID-19 para um Data Frame
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

# %%
# dicionário de variáveis
df_dicionario = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-codebook.csv")

# %%
# retirar colunas source e category
df_dicionario_clean = df_dicionario.drop(columns=['source', 'category']).set_index('column')

# %%
# visualização das 5 primeiras entradas da tabela
df.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# Feitas as importações necessárias e o carregamento dos dados. Decidimos dividir o Data Frame original em 2, pois, este continha dados de Países e Continentes. Desta forma teremos 2 Data Frames, o primeiro (df1) com as informações dos Continentes e o segundo (df2) com as informações dos Países.

# %%
# separando o dataframe entre entradas com e sem OWID
df1 = df[df.iso_code.str.startswith('OWID_')]
df2 = pd.concat([df, df1, df1]).drop_duplicates(keep=False)

# %% [markdown]
# Isto feito, passamos a verificação do tamanho de cada dataset:

# %%
# verificando as dimensões de df1 e df2
print('Dimensões do Dataset - df1',
    '\nVariáveis: ',df1.shape[1], "\n"
      'Entradas: ', df1.shape[0])

print('Dimensões do Dataset - df2',
    '\nVariáveis: ',df2.shape[1], "\n"
      'Entradas: ', df2.shape[0])
# Out:
# Dimensões do Dataset - df1
# Variáveis:  67
# Entradas:  18739
# Dimensões do Dataset - df2
# Variáveis:  67
# Entradas:  220218

# %% [markdown]
# Na sequência, precisamos verificar qual a forma de cada variável através do comando `dtypes`.

# %%
# visualizar todas as linhas do df
pd.set_option('display.max_rows', None)

# Identificando os tipos das colunas
display(df.dtypes)
# Out:
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# reproduction_rate                             float64
# icu_patients                                  float64
# icu_patients_per_million                      float64
# hosp_patients                                 float64
# hosp_patients_per_million                     float64
# weekly_icu_admissions                         float64
# weekly_icu_admissions_per_million             float64
# weekly_hosp_admissions                        float64
# weekly_hosp_admissions_per_million            float64
# total_tests                                   float64
# new_tests                                     float64
# total_tests_per_thousand                      float64
# new_tests_per_thousand                        float64
# new_tests_smoothed                            float64
# new_tests_smoothed_per_thousand               float64
# positive_rate                                 float64
# tests_per_case                                float64
# tests_units                                    object
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# total_boosters                                float64
# new_vaccinations                              float64
# new_vaccinations_smoothed                     float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# total_boosters_per_hundred                    float64
# new_vaccinations_smoothed_per_million         float64
# new_people_vaccinated_smoothed                float64
# new_people_vaccinated_smoothed_per_hundred    float64
# stringency_index                              float64
# population_density                            float64
# median_age                                    float64
# aged_65_older                                 float64
# aged_70_older                                 float64
# gdp_per_capita                                float64
# extreme_poverty                               float64
# cardiovasc_death_rate                         float64
# diabetes_prevalence                           float64
# female_smokers                                float64
# male_smokers                                  float64
# handwashing_facilities                        float64
# hospital_beds_per_thousand                    float64
# life_expectancy                               float64
# human_development_index                       float64
# population                                    float64
# excess_mortality_cumulative_absolute          float64
# excess_mortality_cumulative                   float64
# excess_mortality                              float64
# excess_mortality_cumulative_per_million       float64
# dtype: object

# %% [markdown]
# A partir daí verificamos e quantificamos os dados faltantes. Este passo é importante, pois, em alguns casos seria necessário eliminar certas variáveis caso o objetivo do estudo fosse normalizar os dados para algumas análises qualitativas.

# %%
# classificar em ordem decrescente as variáveis por seus valores ausentes
(df1.isnull().sum()).sort_values(ascending = False)
# Out:
# weekly_icu_admissions                         18739
# weekly_icu_admissions_per_million             18739
# excess_mortality_cumulative_per_million       18708
# excess_mortality                              18708
# excess_mortality_cumulative                   18708
# excess_mortality_cumulative_absolute          18708
# new_tests_per_thousand                        18636
# new_tests                                     18636
# total_tests_per_thousand                      18551
# total_tests                                   18551
# tests_per_case                                18354
# positive_rate                                 18354
# new_tests_smoothed_per_thousand               18354
# new_tests_smoothed                            18354
# tests_units                                   18347
# stringency_index                              17763
# life_expectancy                               17695
# median_age                                    17695
# cardiovasc_death_rate                         17695
# diabetes_prevalence                           17695
# female_smokers                                17695
# male_smokers                                  17695
# handwashing_facilities                        17695
# aged_70_older                                 17695
# aged_65_older                                 17695
# human_development_index                       17695
# hospital_beds_per_thousand                    17695
# reproduction_rate                             16726
# extreme_poverty                               16703
# gdp_per_capita                                16703
# population_density                            16703
# icu_patients_per_million                      15007
# icu_patients                                  15007
# weekly_hosp_admissions_per_million            14873
# weekly_hosp_admissions                        14873
# hosp_patients_per_million                     14795
# hosp_patients                                 14795
# continent                                     13466
# total_boosters                                 9768
# total_boosters_per_hundred                     9768
# people_fully_vaccinated_per_hundred            7407
# people_fully_vaccinated                        7407
# new_vaccinations                               7374
# people_vaccinated                              7320
# people_vaccinated_per_hundred                  7320
# total_vaccinations_per_hundred                 7196
# total_vaccinations                             7196
# new_people_vaccinated_smoothed                 6838
# new_people_vaccinated_smoothed_per_hundred     6838
# new_vaccinations_smoothed                      6775
# new_vaccinations_smoothed_per_million          6775
# total_deaths_per_million                       5497
# new_deaths_smoothed_per_million                5383
# new_cases_smoothed_per_million                 5374
# new_deaths_per_million                         5318
# total_cases_per_million                        5316
# new_cases_per_million                          5309
# total_deaths                                   4482
# new_deaths_smoothed                            4373
# new_cases_smoothed                             4351
# new_deaths                                     4303
# total_cases                                    4288
# new_cases                                      4281
# population                                     1028
# date                                              0
# location                                          0
# iso_code                                          0
# dtype: int64

# %%
# classificar em ordem decrescente as variáveis por seus valores ausentes
(df2.isnull().sum()).sort_values(ascending = False)
# Out:
# weekly_icu_admissions_per_million             212335
# weekly_icu_admissions                         212335
# excess_mortality_cumulative_per_million       212256
# excess_mortality_cumulative                   212256
# excess_mortality_cumulative_absolute          212256
# excess_mortality                              212205
# weekly_hosp_admissions                        204966
# weekly_hosp_admissions_per_million            204966
# total_boosters_per_hundred                    191706
# total_boosters                                191706
# icu_patients                                  191490
# icu_patients_per_million                      191490
# hosp_patients_per_million                     188708
# hosp_patients                                 188708
# new_vaccinations                              175141
# people_fully_vaccinated_per_hundred           169137
# people_fully_vaccinated                       169137
# people_vaccinated                             166570
# people_vaccinated_per_hundred                 166570
# total_vaccinations                            163686
# total_vaccinations_per_hundred                163686
# new_tests_per_thousand                        144918
# new_tests                                     144918
# total_tests_per_thousand                      141019
# total_tests                                   141019
# handwashing_facilities                        126503
# tests_per_case                                126255
# positive_rate                                 124676
# new_tests_smoothed_per_thousand               116638
# new_tests_smoothed                            116638
# tests_units                                   113822
# extreme_poverty                                96910
# new_people_vaccinated_smoothed_per_hundred     91693
# new_people_vaccinated_smoothed                 91693
# new_vaccinations_smoothed_per_million          91291
# new_vaccinations_smoothed                      91291
# male_smokers                                   77496
# female_smokers                                 75501
# hospital_beds_per_thousand                     49932
# reproduction_rate                              44239
# stringency_index                               43731
# human_development_index                        33459
# aged_65_older                                  30402
# gdp_per_capita                                 29848
# new_deaths_smoothed                            29729
# new_deaths_smoothed_per_million                29729
# aged_70_older                                  29376
# cardiovasc_death_rate                          28907
# new_deaths                                     28615
# new_deaths_per_million                         28615
# median_age                                     28367
# total_deaths                                   28355
# total_deaths_per_million                       28355
# diabetes_prevalence                            18926
# population_density                             13727
# new_cases_smoothed                             10584
# new_cases_smoothed_per_million                 10584
# new_cases_per_million                           9455
# new_cases                                       9455
# total_cases_per_million                         9201
# total_cases                                     9201
# life_expectancy                                 1732
# continent                                          0
# population                                         0
# date                                               0
# location                                           0
# iso_code                                           0
# dtype: int64

# %%
# classificar em ordem decrescente as variáveis por seus valores ausentes, em porcentagem
round((df1.isnull().sum() / df1.shape[0]).sort_values(ascending = False),2)
# Out:
# weekly_icu_admissions                         1.00
# weekly_icu_admissions_per_million             1.00
# excess_mortality_cumulative_per_million       1.00
# excess_mortality                              1.00
# excess_mortality_cumulative                   1.00
# excess_mortality_cumulative_absolute          1.00
# new_tests_per_thousand                        0.99
# new_tests                                     0.99
# total_tests_per_thousand                      0.99
# total_tests                                   0.99
# tests_per_case                                0.98
# positive_rate                                 0.98
# new_tests_smoothed_per_thousand               0.98
# new_tests_smoothed                            0.98
# tests_units                                   0.98
# stringency_index                              0.95
# life_expectancy                               0.94
# median_age                                    0.94
# cardiovasc_death_rate                         0.94
# diabetes_prevalence                           0.94
# female_smokers                                0.94
# male_smokers                                  0.94
# handwashing_facilities                        0.94
# aged_70_older                                 0.94
# aged_65_older                                 0.94
# human_development_index                       0.94
# hospital_beds_per_thousand                    0.94
# reproduction_rate                             0.89
# extreme_poverty                               0.89
# gdp_per_capita                                0.89
# population_density                            0.89
# icu_patients_per_million                      0.80
# icu_patients                                  0.80
# weekly_hosp_admissions_per_million            0.79
# weekly_hosp_admissions                        0.79
# hosp_patients_per_million                     0.79
# hosp_patients                                 0.79
# continent                                     0.72
# total_boosters                                0.52
# total_boosters_per_hundred                    0.52
# people_fully_vaccinated_per_hundred           0.40
# people_fully_vaccinated                       0.40
# new_vaccinations                              0.39
# people_vaccinated                             0.39
# people_vaccinated_per_hundred                 0.39
# total_vaccinations_per_hundred                0.38
# total_vaccinations                            0.38
# new_people_vaccinated_smoothed                0.36
# new_people_vaccinated_smoothed_per_hundred    0.36
# new_vaccinations_smoothed                     0.36
# new_vaccinations_smoothed_per_million         0.36
# total_deaths_per_million                      0.29
# new_deaths_smoothed_per_million               0.29
# new_cases_smoothed_per_million                0.29
# new_deaths_per_million                        0.28
# total_cases_per_million                       0.28
# new_cases_per_million                         0.28
# total_deaths                                  0.24
# new_deaths_smoothed                           0.23
# new_cases_smoothed                            0.23
# new_deaths                                    0.23
# total_cases                                   0.23
# new_cases                                     0.23
# population                                    0.05
# date                                          0.00
# location                                      0.00
# iso_code                                      0.00
# dtype: float64

# %%
# classificar em ordem decrescente as variáveis por seus valores ausentes, em porcentagem
round((df2.isnull().sum() / df2.shape[0]).sort_values(ascending = False),2)
# Out:
# weekly_icu_admissions_per_million             0.96
# weekly_icu_admissions                         0.96
# excess_mortality_cumulative_per_million       0.96
# excess_mortality_cumulative                   0.96
# excess_mortality_cumulative_absolute          0.96
# excess_mortality                              0.96
# weekly_hosp_admissions                        0.93
# weekly_hosp_admissions_per_million            0.93
# total_boosters_per_hundred                    0.87
# total_boosters                                0.87
# icu_patients                                  0.87
# icu_patients_per_million                      0.87
# hosp_patients_per_million                     0.86
# hosp_patients                                 0.86
# new_vaccinations                              0.80
# people_fully_vaccinated_per_hundred           0.77
# people_fully_vaccinated                       0.77
# people_vaccinated                             0.76
# people_vaccinated_per_hundred                 0.76
# total_vaccinations                            0.74
# total_vaccinations_per_hundred                0.74
# new_tests_per_thousand                        0.66
# new_tests                                     0.66
# total_tests_per_thousand                      0.64
# total_tests                                   0.64
# handwashing_facilities                        0.57
# tests_per_case                                0.57
# positive_rate                                 0.57
# new_tests_smoothed_per_thousand               0.53
# new_tests_smoothed                            0.53
# tests_units                                   0.52
# extreme_poverty                               0.44
# new_people_vaccinated_smoothed_per_hundred    0.42
# new_people_vaccinated_smoothed                0.42
# new_vaccinations_smoothed_per_million         0.41
# new_vaccinations_smoothed                     0.41
# male_smokers                                  0.35
# female_smokers                                0.34
# hospital_beds_per_thousand                    0.23
# reproduction_rate                             0.20
# stringency_index                              0.20
# human_development_index                       0.15
# aged_65_older                                 0.14
# gdp_per_capita                                0.14
# new_deaths_smoothed                           0.13
# new_deaths_smoothed_per_million               0.13
# aged_70_older                                 0.13
# cardiovasc_death_rate                         0.13
# new_deaths                                    0.13
# new_deaths_per_million                        0.13
# median_age                                    0.13
# total_deaths                                  0.13
# total_deaths_per_million                      0.13
# diabetes_prevalence                           0.09
# population_density                            0.06
# new_cases_smoothed                            0.05
# new_cases_smoothed_per_million                0.05
# new_cases_per_million                         0.04
# new_cases                                     0.04
# total_cases_per_million                       0.04
# total_cases                                   0.04
# life_expectancy                               0.01
# continent                                     0.00
# population                                    0.00
# date                                          0.00
# location                                      0.00
# iso_code                                      0.00
# dtype: float64

# %% [markdown]
# Na verificação dos tipos das variáveis notamos que a coluna **'date'** não está no formato 'datetime'. Portanto, para seguir com as verificações precisamos alterar a coluna para o formato 'datetime'. Além disso, criaremos um checkpoint de controle do nosso dataset original.

# %%
# criando um checkpoint do dataset
df_clean = df2.copy()

# convertendo variável date em data
df.date = pd.to_datetime(df.date).dt.date

# %% [markdown]
# Feita a correção no tipo da coluna **'date'**, se faz necessário verificar a data mais recente em que os dados coletados foram alimentados.

# %%
# verificando a data mais recente do dataset
df_clean.date.max()
# Out:
# '2022-11-30'

# %%
# Identificando o tamanho do DataFrame
print("{} Inputs".format(df_clean.shape[0]))
print("{} Variáveis".format(df_clean.shape[1]))
# Out:
# 220218 Inputs
# 67 Variáveis

# %%
# países com mais casos para a data mais recente (2022-11-30)
top5_casos = df_clean.loc[df_clean.date == '2022-11-30'].sort_values(by="total_cases", ascending=False)[0:5]
top5_casos = top5_casos[['iso_code', 'location', 'date', 'total_cases', 'total_deaths']]
top5_casos
# Out:
#        iso_code       location        date  total_cases  total_deaths
# 225585      USA  United States  2022-11-30   98788140.0     1080444.0
# 98443       IND          India  2022-11-30   44673863.0      530622.0
# 75841       FRA         France  2022-11-30   37886611.0      159019.0
# 80863       DEU        Germany  2022-11-30   36499600.0      157943.0
# 30142       BRA         Brazil  2022-11-30   35227599.0      689665.0

# %% [markdown]
# Verificamos que os países líderes em casos até 30 de novembro de 2022 eram:
#
#    * Estados Unidos - 98.788.140 casos;
#    * India - 44.673.863 casos;
#    * França - 37.886.611 casos;
#    * Alemanha - 36.499.600 casos;
#    * Brasil - 35.227.599 casos.
#
# Agora, vamos verificar os casos de morte.

# %%
# países com mais mortes para a data mais recente (2022-11-30)
top5_mortes = df_clean.loc[df_clean.date == '2022-11-30'].sort_values(by="total_deaths", ascending=False)[0:5]
top5_mortes = top5_mortes[['iso_code', 'location', 'date', 'total_cases', 'total_deaths']]
top5_mortes
# Out:
#        iso_code       location        date  total_cases  total_deaths
# 225585      USA  United States  2022-11-30   98788140.0     1080444.0
# 30142       BRA         Brazil  2022-11-30   35227599.0      689665.0
# 98443       IND          India  2022-11-30   44673863.0      530622.0
# 177286      RUS         Russia  2022-11-30   21284476.0      384103.0
# 137746      MEX         Mexico  2022-11-30    7125176.0      330495.0

# %% [markdown]
# Em relação às mortes, os países que lideravam aos 30 de Novembro de 2022 eram:
#
#    * Estados Unidos - 1.080.444 de mortes;
#    * Brasil - 689.665 de mortes;
#    * India - 530.622 de mortes;
#    * Rússia - 384.103 de mortes;
#    * México - 330.495 de mortes.
#
# Como podemos ver, o países com mais casos e mais mortes variam.
# A título de comparação podemos verificar quais países sofreram maior impacto de casos e mortes.
# Contudo, para esta análise, ao invés dos dados de casos e mortes totais iremos utilizar o total de casos e mortes por milhão, uma vez que como os países possuem populações significativamente diferentes ao usarmos os índices por milhão conseguimos uma melhor uniformização da dimensão dos números de casos.

# %% [markdown]
# Então, antes de fazermos a análise propriamente dita, precisamos verificar os países com mais casos por milhão:

# %%
# países com mais casos por milhão para a data mais recente (2022-11-30)
top5_casos_por_milhao = df_clean.loc[df_clean.date == '2022-11-30'].sort_values(by="total_cases_per_million", ascending=False)[0:5]
top5_casos_por_milhao_filter = top5_casos_por_milhao[['iso_code', 'location', 'date', 'total_cases_per_million', 'total_deaths_per_million']]
top5_casos_por_milhao_filter
# Out:
#        iso_code        location        date  total_cases_per_million  \
# 53665       CYP          Cyprus  2022-11-30               685527.010
# 184777      SMR      San Marino  2022-11-30               657969.724
# 71755       FRO  Faeroe Islands  2022-11-30               652484.139
# 14197       AUT         Austria  2022-11-30               622133.252
# 82857       GIB       Gibraltar  2022-11-30               617682.162
#
#         total_deaths_per_million
# 53665                   1368.293
# 184777                  3532.205
# 71755                    527.138
# 14197                   2372.585
# 82857                   3366.282

# %% [markdown]
# Agora faremos o mesmo para os países com mais mortes por milhão:

# %%
# países com mais mortes por milhão para a data mais recente (2022-11-30)
top5_mortes_por_milhao = df_clean.loc[df_clean.date == '2022-11-30'].sort_values(by="total_deaths_per_million", ascending=False)[0:5]
top5_mortes_por_milhao_filter = top5_mortes_por_milhao[['iso_code', 'location', 'date', 'total_cases_per_million', 'total_deaths_per_million']]
top5_mortes_por_milhao_filter
# Out:
#        iso_code                location        date  total_cases_per_million  \
# 169912      PER                    Peru  2022-11-30               124887.943
# 33115       BGR                Bulgaria  2022-11-30               189806.037
# 28157       BIH  Bosnia and Herzegovina  2022-11-30               123873.290
# 96400       HUN                 Hungary  2022-11-30               217345.834
# 158465      MKD         North Macedonia  2022-11-30               164648.936
#
#         total_deaths_per_million
# 169912                  6385.217
# 33115                   5608.855
# 28157                   5010.623
# 96400                   4844.540
# 158465                  4570.105

# %% [markdown]
# Uma vez que temos os 5 países com mais casos e mais mortes por milhão, vamos analisar a relação de casos por mortes totais e por milhão:

# %%
# Verificar relação da proporção de casos por mortes dos 5 países com mais casos e mais mortes totais
proporcao_casos_eua = df_clean.loc[225569, 'total_cases'] / df_clean.loc[225569, 'total_deaths']
print("O número total de casos por morte nos Estados Unidos foi de {}".format(proporcao_casos_eua.round(2)))

proporcao_casos_ind = df_clean.loc[98435, 'total_cases'] / df_clean.loc[98435, 'total_deaths']
print("O número total de casos por morte na India foi de {}".format(proporcao_casos_ind.round(2)))

proporcao_casos_fra = df_clean.loc[75833, 'total_cases'] / df_clean.loc[75833, 'total_deaths']
print("O número total de casos por morte na França foi de {}".format(proporcao_casos_fra.round(2)))

proporcao_casos_deu = df_clean.loc[80855, 'total_cases'] / df_clean.loc[80855, 'total_deaths']
print("O número total de casos por morte na Alemanha foi de {}".format(proporcao_casos_deu.round(2)))

proporcao_casos_bra = df_clean.loc[30142, 'total_cases'] / df_clean.loc[30142, 'total_deaths']
print("O número total de casos por morte no Brasil foi de {}".format(proporcao_casos_bra.round(2)))

proporcao_casos_rus = df_clean.loc[177277, 'total_cases'] / df_clean.loc[177277, 'total_deaths']
print("O número total de casos por morte na Rússia foi de {}".format(proporcao_casos_rus.round(2)))

proporcao_casos_mex = df_clean.loc[137738, 'total_cases'] / df_clean.loc[137738, 'total_deaths']
print("O número total de casos por morte no México foi de {}".format(proporcao_casos_mex.round(2)))
# Out:
# O número total de casos por morte nos Estados Unidos foi de 91.22
# O número total de casos por morte na India foi de 84.19
# O número total de casos por morte na França foi de 236.49
# O número total de casos por morte na Alemanha foi de 231.16
# O número total de casos por morte no Brasil foi de 51.08
# O número total de casos por morte na Rússia foi de 55.35
# O número total de casos por morte no México foi de 21.56

# %%
# Verificar relação da proporção de casos por mortes por milhão dos 5 países com mais casos e mais mortes por milhão
# relação de casos milhão por mortes por milhão, 5 top países com mais casos por milhão
proporcao_casos_cyp = df_clean.loc[53664, 'total_cases_per_million'] / df_clean.loc[53664, 'total_deaths_per_million']
print("O número total de casos por morte por milhão no Chipre foi de {}".format(proporcao_casos_cyp.round(2)))

proporcao_casos_smr = df_clean.loc[184768, 'total_cases_per_million'] / df_clean.loc[184768, 'total_deaths_per_million']
print("O número total de casos por morte por milhão em San Marino foi de {}".format(proporcao_casos_smr.round(2)))

proporcao_casos_fro = df_clean.loc[71747, 'total_cases_per_million'] / df_clean.loc[71747, 'total_deaths_per_million']
print("O número total de casos por morte por milhão nas Ilhas Faeroe foi de {}".format(proporcao_casos_fro.round(2)))

proporcao_casos_aut = df_clean.loc[14197, 'total_cases_per_million'] / df_clean.loc[14197, 'total_deaths_per_million']
print("O número total de casos por morte por milhão na Austria foi de {}".format(proporcao_casos_aut.round(2)))

proporcao_casos_gib = df_clean.loc[82849, 'total_cases_per_million'] / df_clean.loc[82849, 'total_deaths_per_million']
print("O número total de casos por morte por milhão em Gibraltar de {}".format(proporcao_casos_gib.round(2)))

# relação de casos milhão por mortes por milhão, 5 top países com mais mortes por milhão

proporcao_casos_per = df_clean.loc[169903, 'total_cases_per_million'] / df_clean.loc[169903, 'total_deaths_per_million']
print("O número total de casos por morte por milhão no Peru foi de {}".format(proporcao_casos_per.round(2)))

proporcao_casos_bgr = df_clean.loc[33115, 'total_cases_per_million'] / df_clean.loc[33115, 'total_deaths_per_million']
print("O número total de casos por morte por milhão na Bulgária foi de {}".format(proporcao_casos_bgr.round(2)))

proporcao_casos_bih = df_clean.loc[28157, 'total_cases_per_million'] / df_clean.loc[28157, 'total_deaths_per_million']
print("O número total de casos por morte por milhão na Bósnia e Herzegovina foi de {}".format(proporcao_casos_bih.round(2)))

proporcao_casos_hun = df_clean.loc[96392, 'total_cases_per_million'] / df_clean.loc[96392, 'total_deaths_per_million']
print("O número total de casos por morte por milhão na Hungria foi de {}".format(proporcao_casos_hun.round(2)))

proporcao_casos_mkd = df_clean.loc[158457, 'total_cases_per_million'] / df_clean.loc[158457, 'total_deaths_per_million']
print("O número total de casos por morte por milhão na Macedônia do Norte de {}".format(proporcao_casos_mkd.round(2)))
# Out:
# O número total de casos por morte por milhão no Chipre foi de 501.01
# O número total de casos por morte por milhão em San Marino foi de 183.18
# O número total de casos por morte por milhão nas Ilhas Faeroe foi de 1237.79
# O número total de casos por morte por milhão na Austria foi de 262.22
# O número total de casos por morte por milhão em Gibraltar de 183.49
# O número total de casos por morte por milhão no Peru foi de 19.29
# O número total de casos por morte por milhão na Bulgária foi de 33.84
# O número total de casos por morte por milhão na Bósnia e Herzegovina foi de 24.72
# O número total de casos por morte por milhão na Hungria foi de 44.79
# O número total de casos por morte por milhão na Macedônia do Norte de 36.01

# %% [markdown]
# Com isso conseguimos ver que alguns países se saíram melhor que outros na relação entre casos e mortes.
#
# Relação de número de casos por número de mortes para os 5 Países com mais casos:
#
# * Estados Unidos - 91,43
# * Índia - 84,19
# * França - 238,25
# * Alemanha - 231,09
# * Brasil - 51,08
#
# Ou seja, entre os 5 países com mais casos, as relações da França e Alemanha foram consideravelmente superiores ao Estados Unidos, a India e o Brasil. Isso significa que estes países perderam menos pessoas apesar da quantidade elevada de casos.
#
# Já em relação ao número de casos por número de mortes para os 5 Países com mais mortes, temos:
#
# * Estados Unidos - 91,43
# * Brasil - 51,08
# * Índia - 84,19
# * Rússia - 55,41
# * México - 21,56
#
# Como podemos ver, entre os 5 países com mais mortes, a relação encontrada é mais homogênea, o que significa que estes países tiveram um combate menos eficiente do COVID-19. Em especial o México, em que registrou uma morte a cada 21,56 casos.
#
# Por outro lado, ao fazermos a mesma análise entre os países com mais casos por milhão e com mais mortes por milhão, temos:
#
# Relação do número de casos por milhão por mortes por milhão para os 5 Países com mais casos por milhão:
#
# * Chipre - 501,01
# * San Marino - 186,28
# * Ilhas Faeroe - 1237,79
# * Áustria - 262,22
# * Gibraltar - 183,49
#
# Relação do número de casos por milhão por mortes por milhão para os 5 Países com mais mortes por milhão:
#
# * Peru - 19,56
# * Bulgária - 33,84
# * Bósnia e Herzegovina - 24,72
# * Hungria - 44,86
# * Macedônia do Norte - 36,03
#
# Portanto, como vemos no caso dos países com mais casos por milhão. Estes países obtiveram altos índices na proporção entre casos por milhão por mortes por milhão. Por outro lado, nos países com mais mortes por milhão os índices na proporção entre casos por milhão por mortes por milhão obtidos se mostram extremamente baixas, com destaque do Peru que registrou uma morte a cada caso.
#
# Não é o objetivo discutir os motivos que influenciam estes resultados, entretanto, é inegável que fatores políticos, sociais, econômicos e até geográficos causaram impactos significativos.

# %% [markdown]
# Voltando aos países com maior total de mortes totais, para melhorar a visualização, vamos plotar um gráfico de barras.

# %%
# gráfico de barras para total de mortes
top_5_total_deaths = df_clean.loc[df_clean.date == '2020-11-30', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]

fig, ax = plt.subplots(figsize=(15,10))

ax.bar('location', 'total_deaths', data=top_5_total_deaths)

plt.tight_layout()

# %% [markdown]
# ###Como o vírus está progredindo?
#
# Uma das maiores preocupações das organizações de saúde é a progressão do número de casos e mortes no mundo.
#
# Uma das melhores formas de visualizarmos a evolução ao longo do tempo, é o gráfico de linhas. Por isso, vamos plotar um gráfico de linha para demonstrar e evolução de mortes no mundo.

# %%
# gráfico de linha para mortes no mundo
df1.loc[df1.location == "World", "total_deaths"].reset_index(drop=True).plot(figsize=(10,8));

# %% [markdown]
# Por fim, em relação ao aspecto global, como última análise, vamos plotar um gráfico da dispersão da relação entre total de mortes e PIB per capita:

# %%
# plotando disperão do número de mortos por renda per capita
plt.figure(figsize = (16, 8))
sns.scatterplot(data=df_clean, x='gdp_per_capita', y='total_deaths')
plt.xlabel("PIB per Capita", size = 14)
plt.ylabel("Total de mortes", size = 14)
plt.show()

# %% [markdown]
# ### Análise Exploratória para o Brasil
#
# Agora passamos a análise exploratória dos dados do Brasil, em que iremos verificar algumas questões mais a fundo:
#
# * Identificar quando foi registrada a primeira morte no Brasil
# * Identificar quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado.
# * Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

# %%
# Criando DataFrame para o Brasil
df_brasil = df.loc[df.location == "Brazil"].copy()
df_brasil
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
#
# 29933               NaN                                      NaN
# 29934               NaN                                      NaN
# 29935               NaN                                      NaN
# 29936               NaN                                      NaN
# 29937               NaN                                      NaN
# 29938               NaN                                      NaN
# 29939               NaN                                      NaN
# 29940               NaN                                      NaN
# 29941               NaN                                      NaN
# 29942               NaN                                      NaN
# 29943               NaN                                      NaN
# 29944               NaN                                      NaN
# 29945               NaN                                      NaN
# 29946               NaN                                      NaN
# 29947               NaN                                      NaN
# 29948               NaN                                      NaN
# 29949               NaN                                      NaN
# 29950               NaN                                      NaN
# 29951               NaN                                      NaN
# 29952               NaN                                      NaN
# 29953               NaN                                      NaN
# 29954               NaN                                      NaN
# 29955               NaN                                      NaN
# 29956               NaN                                      NaN
# 29957               NaN                                      NaN
# 29958               NaN                                      NaN
# 29959              8.07                              3577.321839
# 29960               NaN                                      NaN
# 29961               NaN                                      NaN
# 29962               NaN                                      NaN
# 29963               NaN                                      NaN
# 29964               NaN                                      NaN
# 29965               NaN                                      NaN
# 29966               NaN                                      NaN
# 29967               NaN                                      NaN
# 29968               NaN                                      NaN
# 29969               NaN                                      NaN
# 29970               NaN                                      NaN
# 29971               NaN                                      NaN
# 29972               NaN                                      NaN
# 29973               NaN                                      NaN
# 29974               NaN                                      NaN
# 29975               NaN                                      NaN
# 29976               NaN                                      NaN
# 29977               NaN                                      NaN
# 29978               NaN                                      NaN
# 29979               NaN                                      NaN
# 29980               NaN                                      NaN
# 29981               NaN                                      NaN
# 29982               NaN                                      NaN
# 29983               NaN                                      NaN
# 29984               NaN                                      NaN
# 29985               NaN                                      NaN
# 29986               NaN                                      NaN
# 29987               NaN                                      NaN
# 29988               NaN                                      NaN
# 29989             13.94                              3656.777143
# 29990               NaN                                      NaN
# 29991               NaN                                      NaN
# 29992               NaN                                      NaN
# 29993               NaN                                      NaN
# 29994               NaN                                      NaN
# 29995               NaN                                      NaN
# 29996               NaN                                      NaN
# 29997               NaN                                      NaN
# 29998               NaN                                      NaN
# 29999               NaN                                      NaN
# 30000               NaN                                      NaN
# 30001               NaN                                      NaN
# 30002               NaN                                      NaN
# 30003               NaN                                      NaN
# 30004               NaN                                      NaN
# 30005               NaN                                      NaN
# 30006               NaN                                      NaN
# 30007               NaN                                      NaN
# 30008               NaN                                      NaN
# 30009               NaN                                      NaN
# 30010               NaN                                      NaN
# 30011               NaN                                      NaN
# 30012               NaN                                      NaN
# 30013               NaN                                      NaN
# 30014               NaN                                      NaN
# 30015               NaN                                      NaN
# 30016               NaN                                      NaN
# 30017               NaN                                      NaN
# 30018               NaN                                      NaN
# 30019               NaN                                      NaN
# 30020              7.35                              3700.151106
# 30021               NaN                                      NaN
# 30022               NaN                                      NaN
# 30023               NaN                                      NaN
# 30024               NaN                                      NaN
# 30025               NaN                                      NaN
# 30026               NaN                                      NaN
# 30027               NaN                                      NaN
# 30028               NaN                                      NaN
# 30029               NaN                                      NaN
# 30030               NaN                                      NaN
# 30031               NaN                                      NaN
# 30032               NaN                                      NaN
# 30033               NaN                                      NaN
# 30034               NaN                                      NaN
# 30035               NaN                                      NaN
# 30036               NaN                                      NaN
# 30037               NaN                                      NaN
# 30038               NaN                                      NaN
# 30039               NaN                                      NaN
# 30040               NaN                                      NaN
# 30041               NaN                                      NaN
# 30042               NaN                                      NaN
# 30043               NaN                                      NaN
# 30044               NaN                                      NaN
# 30045               NaN                                      NaN
# 30046               NaN                                      NaN
# 30047               NaN                                      NaN
# 30048               NaN                                      NaN
# 30049               NaN                                      NaN
# 30050               NaN                                      NaN
# 30051             11.51                              3764.736930
# 30052               NaN                                      NaN
# 30053               NaN                                      NaN
# 30054               NaN                                      NaN
# 30055               NaN                                      NaN
# 30056               NaN                                      NaN
# 30057               NaN                                      NaN
# 30058               NaN                                      NaN
# 30059               NaN                                      NaN
# 30060               NaN                                      NaN
# 30061               NaN                                      NaN
# 30062               NaN                                      NaN
# 30063               NaN                                      NaN
# 30064               NaN                                      NaN
# 30065               NaN                                      NaN
# 30066               NaN                                      NaN
# 30067               NaN                                      NaN
# 30068               NaN                                      NaN
# 30069               NaN                                      NaN
# 30070               NaN                                      NaN
# 30071               NaN                                      NaN
# 30072               NaN                                      NaN
# 30073               NaN                                      NaN
# 30074               NaN                                      NaN
# 30075               NaN                                      NaN
# 30076               NaN                                      NaN
# 30077               NaN                                      NaN
# 30078               NaN                                      NaN
# 30079               NaN                                      NaN
# 30080               NaN                                      NaN
# 30081              7.04                              3802.115449
# 30082               NaN                                      NaN
# 30083               NaN                                      NaN
# 30084               NaN                                      NaN
# 30085               NaN                                      NaN
# 30086               NaN                                      NaN
# 30087               NaN                                      NaN
# 30088               NaN                                      NaN
# 30089               NaN                                      NaN
# 30090               NaN                                      NaN
# 30091               NaN                                      NaN
# 30092               NaN                                      NaN
# 30093               NaN                                      NaN
# 30094               NaN                                      NaN
# 30095               NaN                                      NaN
# 30096               NaN                                      NaN
# 30097               NaN                                      NaN
# 30098               NaN                                      NaN
# 30099               NaN                                      NaN
# 30100               NaN                                      NaN
# 30101               NaN                                      NaN
# 30102               NaN                                      NaN
# 30103               NaN                                      NaN
# 30104               NaN                                      NaN
# 30105               NaN                                      NaN
# 30106               NaN                                      NaN
# 30107               NaN                                      NaN
# 30108               NaN                                      NaN
# 30109               NaN                                      NaN
# 30110               NaN                                      NaN
# 30111               NaN                                      NaN
# 30112               NaN                                      NaN
# 30113               NaN                                      NaN
# 30114               NaN                                      NaN
# 30115               NaN                                      NaN
# 30116               NaN                                      NaN
# 30117               NaN                                      NaN
# 30118               NaN                                      NaN
# 30119               NaN                                      NaN
# 30120               NaN                                      NaN
# 30121               NaN                                      NaN
# 30122               NaN                                      NaN
# 30123               NaN                                      NaN
# 30124               NaN                                      NaN
# 30125               NaN                                      NaN
# 30126               NaN                                      NaN
# 30127               NaN                                      NaN
# 30128               NaN                                      NaN
# 30129               NaN                                      NaN
# 30130               NaN                                      NaN
# 30131               NaN                                      NaN
# 30132               NaN                                      NaN
# 30133               NaN                                      NaN
# 30134               NaN                                      NaN
# 30135               NaN                                      NaN
# 30136               NaN                                      NaN
# 30137               NaN                                      NaN
# 30138               NaN                                      NaN
# 30139               NaN                                      NaN
# 30140               NaN                                      NaN
# 30141               NaN                                      NaN
# 30142               NaN                                      NaN
#
# [1009 rows x 67 columns]

# %%
# verificando data mais recente para dados do Brasil
df_brasil.date.max()
# Out:
# datetime.date(2022, 11, 30)

# %%
# verificando data mais antiga para dados do Brasil
df_brasil.date.min()
# Out:
# datetime.date(2020, 2, 26)

# %% [markdown]
# Como podemos ver acima, nosso dataset inclui dados entre os períodos de **26 de fevereiro de 2020** a **31 de novembro de 2022**.

# %%
# Shape do DataFrame do Brasil
df_brasil.shape
# Out:
# (1009, 67)

# %%
# Encontrando o primeiro caso registrado no Brasil
primeiro_caso_br = df_brasil.loc[df.total_cases == 1].sort_values(by="date", ascending=False).min()
primeiro_caso_br
# Out:
# iso_code                                                BRA
# continent                                     South America
# location                                             Brazil
# date                                             2020-02-26
# total_cases                                             1.0
# new_cases                                               0.0
# new_cases_smoothed                                      NaN
# total_deaths                                            NaN
# new_deaths                                              NaN
# new_deaths_smoothed                                     NaN
# total_cases_per_million                               0.005
# new_cases_per_million                                   0.0
# new_cases_smoothed_per_million                          NaN
# total_deaths_per_million                                NaN
# new_deaths_per_million                                  NaN
# new_deaths_smoothed_per_million                         NaN
# reproduction_rate                                       NaN
# icu_patients                                            NaN
# icu_patients_per_million                                NaN
# hosp_patients                                           NaN
# hosp_patients_per_million                               NaN
# weekly_icu_admissions                                   NaN
# weekly_icu_admissions_per_million                       NaN
# weekly_hosp_admissions                                  NaN
# weekly_hosp_admissions_per_million                      NaN
# total_tests                                             NaN
# new_tests                                               NaN
# total_tests_per_thousand                                NaN
# new_tests_per_thousand                                  NaN
# new_tests_smoothed                                      NaN
# new_tests_smoothed_per_thousand                         NaN
# positive_rate                                           NaN
# tests_per_case                                          NaN
# tests_units                                            None
# total_vaccinations                                      NaN
# people_vaccinated                                       NaN
# people_fully_vaccinated                                 NaN
# total_boosters                                          NaN
# new_vaccinations                                        NaN
# new_vaccinations_smoothed                               NaN
# total_vaccinations_per_hundred                          NaN
# people_vaccinated_per_hundred                           NaN
# people_fully_vaccinated_per_hundred                     NaN
# total_boosters_per_hundred                              NaN
# new_vaccinations_smoothed_per_million                   NaN
# new_people_vaccinated_smoothed                          NaN
# new_people_vaccinated_smoothed_per_hundred              NaN
# stringency_index                                       5.56
# population_density                                    25.04
# median_age                                             33.5
# aged_65_older                                         8.552
# aged_70_older                                          5.06
# gdp_per_capita                                    14103.452
# extreme_poverty                                         3.4
# cardiovasc_death_rate                               177.961
# diabetes_prevalence                                    8.11
# female_smokers                                         10.1
# male_smokers                                           17.9
# handwashing_facilities                                  NaN
# hospital_beds_per_thousand                              2.2
# life_expectancy                                       75.88
# human_development_index                               0.765
# population                                      215313504.0
# excess_mortality_cumulative_absolute                    NaN
# excess_mortality_cumulative                             NaN
# excess_mortality                                        NaN
# excess_mortality_cumulative_per_million                 NaN
# dtype: object

# %%
# primeira morte
df_brasil.loc[df_brasil['new_cases'] == 1].head(1)
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 29134      BRA  South America   Brazil  2020-02-26          1.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 29134                 NaN           NaN         NaN                  NaN  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 29134          17.9                     NaN                         2.2
#
#        life_expectancy  human_development_index   population  \
# 29134            75.88                    0.765  215313504.0
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 29134                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 29134               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
# Encontrando a primeira morte registrada no Brasil
primeira_morte_br = df_brasil.loc[df.total_deaths == 1].sort_values(by="date", ascending=False).min()
primeira_morte_br
# Out:
# iso_code                                                BRA
# continent                                     South America
# location                                             Brazil
# date                                             2020-03-17
# total_cases                                           321.0
# new_cases                                             121.0
# new_cases_smoothed                                   41.429
# total_deaths                                            1.0
# new_deaths                                              1.0
# new_deaths_smoothed                                     NaN
# total_cases_per_million                               1.491
# new_cases_per_million                                 0.562
# new_cases_smoothed_per_million                        0.192
# total_deaths_per_million                              0.005
# new_deaths_per_million                                0.005
# new_deaths_smoothed_per_million                         NaN
# reproduction_rate                                      2.45
# icu_patients                                            NaN
# icu_patients_per_million                                NaN
# hosp_patients                                           NaN
# hosp_patients_per_million                               NaN
# weekly_icu_admissions                                   NaN
# weekly_icu_admissions_per_million                       NaN
# weekly_hosp_admissions                                  NaN
# weekly_hosp_admissions_per_million                      NaN
# total_tests                                             NaN
# new_tests                                               NaN
# total_tests_per_thousand                                NaN
# new_tests_per_thousand                                  NaN
# new_tests_smoothed                                      NaN
# new_tests_smoothed_per_thousand                         NaN
# positive_rate                                           NaN
# tests_per_case                                          NaN
# tests_units                                            None
# total_vaccinations                                      NaN
# people_vaccinated                                       NaN
# people_fully_vaccinated                                 NaN
# total_boosters                                          NaN
# new_vaccinations                                        NaN
# new_vaccinations_smoothed                               NaN
# total_vaccinations_per_hundred                          NaN
# people_vaccinated_per_hundred                           NaN
# people_fully_vaccinated_per_hundred                     NaN
# total_boosters_per_hundred                              NaN
# new_vaccinations_smoothed_per_million                   NaN
# new_people_vaccinated_smoothed                          NaN
# new_people_vaccinated_smoothed_per_hundred              NaN
# stringency_index                                      57.87
# population_density                                    25.04
# median_age                                             33.5
# aged_65_older                                         8.552
# aged_70_older                                          5.06
# gdp_per_capita                                    14103.452
# extreme_poverty                                         3.4
# cardiovasc_death_rate                               177.961
# diabetes_prevalence                                    8.11
# female_smokers                                         10.1
# male_smokers                                           17.9
# handwashing_facilities                                  NaN
# hospital_beds_per_thousand                              2.2
# life_expectancy                                       75.88
# human_development_index                               0.765
# population                                      215313504.0
# excess_mortality_cumulative_absolute                    NaN
# excess_mortality_cumulative                             NaN
# excess_mortality                                        NaN
# excess_mortality_cumulative_per_million                 NaN
# dtype: object

# %%
# primeira morte
df_brasil.loc[df_brasil['new_deaths'] == 1].head(1)
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 29154      BRA  South America   Brazil  2020-03-17        321.0      121.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 29154              41.429           1.0         1.0                  NaN  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 29154          17.9                     NaN                         2.2
#
#        life_expectancy  human_development_index   population  \
# 29154            75.88                    0.765  215313504.0
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 29154                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 29154               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
# achando a diferença entre o primeiro caso e primeira morte registrados
diferenca = primeira_morte_br.date - primeiro_caso_br.date
pd.to_timedelta(diferenca, unit='days', errors='coerce')
print("A diferença entre o primeiro caso e a primeira morte registrados foi de {} dias.".format(str(diferenca).split(' ',1)[0]))
# Out:
# A diferença entre o primeiro caso e a primeira morte registrados foi de 20 dias.

# %% [markdown]
# ## Data do primeiro caso, primeira morte e intervalo entre o primeiro caso e primeira morte:
#
# Como vemos, o registro do primeiro caso segundo nosso dataset foi na data de 26 de fevereiro de 2020. Já a primeira morte foi registrada na data de 17 de março de 2020.
# Portanto a diferença entre o registro do primeiro caso e da primeira morte foi de **20 dias**.

# %% [markdown]
# ## Evolução dos casos e mortes no Brasil
#
# Por fim, vamos plotar os gráficos de linha dos casos e mortes no Brasil.

# %%
# Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.
x = list(range(1009))
z = df_brasil['total_cases']
z2 = df_brasil['total_deaths']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(9, 7))
ax1.set_title('Casos no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Casos')
ax1.plot(x, z)

ax2.set_title('Casos no Brasil (Escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Casos')
ax2.set_yscale('log')
ax2.plot(x, z)

ax3.set_title('Mortes no Brasil')
ax3.set_xlabel('Dias')
ax3.set_ylabel('Mortes')
ax3.plot(x, z2)

ax4.set_title('Mortes no Brasil (Escala logarítmica')
ax4.set_xlabel('Dias')
ax4.set_ylabel('Mortes')
ax4.set_yscale('log')
ax4.plot(x, z2)
plt.tight_layout()

# %% [markdown]
# ## Conclusão
#
# Antes de avançarmos à conclusão é importante e extremamente relevante lembramos que os dados continuam a ser atualizados, pois apesar de enfraquecida, a pandemia e por consequência seu combate continua acontecendo neste momento (dezembro de 2022). Portanto, este projeto representa uma fotografia deste momento, logo os resultados obtidos refletem tão somente o intervalo no qual o dataset foi analisado.
#
# Isto dito, chegamos a algumas conclusões dentre as quais se destacam:
#
# * Os Estados Unidos registraram os maiores números de casos e de mortes no planeta todo.
# * Em relação a proporção de casos por mortes totais entre os 5 países com mais casos, assim como entre os 5 países com mais mortes os Estados Unidos registraram uma morte a cada 91,43 casos.
# * Por outro lado, o país em que esta proporção foi mais grave foi o México, ainda que apenas o quinto país com mais mortes, a proporção de casos por mortes, este país registrou uma morte a cada 21,56 casos.
# * Já considerando os 5 países com mais casos por milhão e mais mortes por milhão encontramos o Chipre e o Peru, respectivamente, como líderes nestas situações.
# * Comparativamente a proporção de casos por milhão por mortes por milhão entre os 5 países com mais casos por milhão e mais mortes por milhão, observamos uma diferença significativa entre estas proporções. Como destaque verificamos que o caso mais grave foi o do Peru que obteve uma morte a cada 19,56 casos por milhão.
# * Em relação a evolução das mortes por COVID-19 no mundo, verificamos que o gráfico apresenta um comportamento em **"S"**.
# * No que tange a dispersão de mortes por PIB per capita, observamos que a maior concentração de mortes está na faixa próxima a U$55.000,00.
#
# COVID-19 no Brasil:
#
# * Apesar de o intervalo entre o registro do primeiro caso e o registro da primeira morte tenha sido de 20 dias.
# * A evolução dos casos no Brasil está em crescimento avassalador.
# * No geral, casos e mortes ainda estão crescendo.
#
# Muitas outras análises podem ser retiradas desse conjunto de dados, mas com essa análise inicial já conseguimos retirar muitas informações que nos permitiram obter as conclusões acima.
